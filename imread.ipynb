# %% [markdown]
# <a href="https://colab.research.google.com/github/agnessheila/images/blob/master/imread.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/agnessheila/images.git
# Out:
# Cloning into 'images'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 41 (delta 12), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (41/41), done.

# %%
image = cv2.imread("images/1.jpg")
h=image.shape[0]
w=image.shape[1]
c=image.shape[2]

print(h,w,c)
# Out:
# 399 600 3

# %%
(b,g,r) = image[10,20]
print(b,g,r)
# Out:
# 25 79 62

# %%
plt.imshow(image)
