# %% [markdown]
# <a href="https://colab.research.google.com/github/agnessheila/images/blob/master/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/agnessheila/test.git
# Out:
# Cloning into 'test'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (14/14), done.
# fatal: destination path 'test' already exists and is not an empty directory.

# %%
image = cv2.imread("test/6.jpg")
h=image.shape[0]
w=image.shape[1]
c=image.shape[2]

print(h,w,c)
# Out:
# 1024 1536 3

# %%
(b,g,r) = image[10,20]
print(b,g,r)
# Out:
# 5 8 12

# %%
plt.imshow(image)
